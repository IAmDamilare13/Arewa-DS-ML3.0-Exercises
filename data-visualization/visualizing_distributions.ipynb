# %% [markdown]
# # Data Visualization - Distribution
#
#
# Build a notebook to tell a story about this dataset, and make sure to use histograms when discussing it.
#
# A notebook is presented with annotations about this dataset, including its source, and uses at least 5 histograms to discover facts about the data.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Import data
crimes = pd.read_csv('../data/us_crime_rates_1960_2014.csv', index_col='Year')

crimes.head()
# Out:
#       Population    Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960   179323175  3384200   288460   3095700    9110          17190   107840
# 1961   182992000  3488000   289390   3198600    8740          17220   106670
# 1962   185771000  3752200   301510   3450700    8530          17550   110860
# 1963   188483000  4109500   316970   3792500    8640          17650   116470
# 1964   191141000  4564600   364220   4200400    9360          21420   130390
#
#       Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960              154320    912100        1855400         328200
# 1961              156760    949600        1913000         336000
# 1962              164570    994300        2089600         366800
# 1963              174210   1086400        2297800         408300
# 1964              203050   1213200        2514400         472800

# %%
# crimes.columns
crimes.boxplot(['Violent', 'Property', 'Murder', 'Forcible_Rape', 'Robbery', 'Aggravated_assault', 'Burglary', 'Larceny_Theft', 'Vehicle_Theft'])
plt.show()

# %%
crimes.hist('Total', )


crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55 entries, 1960 to 2014
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Population          55 non-null     int64
#  1   Total               55 non-null     int64
#  2   Violent             55 non-null     int64
#  3   Property            55 non-null     int64
#  4   Murder              55 non-null     int64
#  5   Forcible_Rape       55 non-null     int64
#  6   Robbery             55 non-null     int64
#  7   Aggravated_assault  55 non-null     int64
#  8   Burglary            55 non-null     int64
#  9   Larceny_Theft       55 non-null     int64
#  10  Vehicle_Theft       55 non-null     int64
# dtypes: int64(11)
# memory usage: 5.2 KB

# %%
crimes.boxplot(['Violent', 'Robbery', 'Aggravated_assault'])
plt.show()

# %%
crimes.boxplot(['Violent', 'Aggravated_assault'])
plt.show()

# %%
crimes.boxplot(['Murder', 'Forcible_Rape'])
plt.show()

# %%
crimes.boxplot(['Violent', 'Vehicle_Theft'])
plt.show()

# %%
crimes.boxplot(['Aggravated_assault', 'Vehicle_Theft'])
plt.show()

# %%
crimes.boxplot(['Murder', 'Robbery'])
plt.show()
